# %%
import pandas as pd
import numpy as np

# %%
movie = pd.read_csv("data/movie.csv")
movie.head(3) 
# movie.head() => 만일 지정하지 않은 경우 기본적으로 5개의 행만 가져온다
# Out:
#    color   director_name  num_critic_for_reviews  duration  \
# 0  Color   James Cameron                   723.0     178.0
# 1  Color  Gore Verbinski                   302.0     169.0
# 2  Color      Sam Mendes                   602.0     148.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy  ...
# 2                 11000.0  200074175.0        Action|Adventure|Thriller  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# ...

# %%
movie.columns # 열의 내용을 알 수 있다
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
movie.index # 행의 수를 알 수 있다
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
movie.values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]], dtype=object)

# %%
movie.dtypes # 데이터 타입을 알 수 있다
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movie['num_critic_for_reviews']
# Out:
# 0       723.0
# 1       302.0
# 2       602.0
# 3       813.0
# 4         NaN
#         ...
# 4911      1.0
# 4912     43.0
# 4913     13.0
# 4914     14.0
# 4915     43.0
# Name: num_critic_for_reviews, Length: 4916, dtype: float64

# %%
df_greather_than_50 = movie['num_critic_for_reviews']>50 #변수에 저장하여 마치 단축키 처럼 활용하는 것이 가능하다

# %%
movie[df_greather_than_50].T #transpose(전치)
# Out:
#                                                                         0     \
# color                                                                  Color
# director_name                                                  James Cameron
# num_critic_for_reviews                                                 723.0
# duration                                                               178.0
# director_facebook_likes                                                  0.0
# actor_3_facebook_likes                                                 855.0
# actor_2_name                                                Joel David Moore
# actor_1_facebook_likes                                                1000.0
# gross                                                            760505847.0
# genres                                       Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                     CCH Pounder
# ...

# %%
movie['director_name'] #저장되어 있는 감독 명을 가져온다
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
type(movie['director_name']) #Series는 하나의 열만의 데이터, #DataFrame은 엑셀과 같은 테이블이다
# Out:
# pandas.core.series.Series

# %%
director = movie['director_name']
director.name
# Out:
# 'director_name'

# %%
director.to_frame() # series to dataframe
# Out:
#           director_name
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# ...                 ...
# 4911        Scott Smith
# 4912                NaN
# 4913   Benjamin Roberds
# 4914        Daniel Hsia
# 4915           Jon Gunn
#
# [4916 rows x 1 columns]

# %%
junhang_set = set([1, 2, 3]) #set으로 변경하는 함수
junhang_set
# Out:
# {1, 2, 3}

# %%
s_attr_methods = set(dir(pd.Series)) #pd => import pandas as pd로 별칭으로 축약하여 사용 가능
len(s_attr_methods)
# Out:
# 419

# %%
df_attr_methods = set(dir(pd.DataFrame)) #Dataframe은 Series가 여러 개 모인 것(테이블)
len(df_attr_methods)
# Out:
# 437

# %%
len(s_attr_methods & df_attr_methods) #len으로 길이를 확인 가능(?)
# Out:
# 362

# %%
director = movie['director_name']
actor_1_fb_likes = movie['actor_1_facebook_likes']

# %%
director.head() # 앞의 다섯 개를 가져온다
# Out:
# 0        James Cameron
# 1       Gore Verbinski
# 2           Sam Mendes
# 3    Christopher Nolan
# 4          Doug Walker
# Name: director_name, dtype: object

# %%
director.tail() # 뒤의 다섯 개를 가져온다
# Out:
# 4911         Scott Smith
# 4912                 NaN
# 4913    Benjamin Roberds
# 4914         Daniel Hsia
# 4915            Jon Gunn
# Name: director_name, dtype: object

# %%
director.tail(10) # 숫자를 기입하면 원하는 수만큼 가져올 수 있다
# Out:
# 4906       Shane Carruth
# 4907    Neill Dela Llana
# 4908    Robert Rodriguez
# 4909     Anthony Vallone
# 4910        Edward Burns
# 4911         Scott Smith
# 4912                 NaN
# 4913    Benjamin Roberds
# 4914         Daniel Hsia
# 4915            Jon Gunn
# Name: director_name, dtype: object

# %%
from IPython.display import display

# %%
director.shape # 데이터의 형태
# Out:
# (4916,)

# %%
actor_1_fb_likes.quantile()
# Out:
# 982.0

# %%
actor_1_fb_likes.min(), actor_1_fb_likes.max(), actor_1_fb_likes.mean(), 
    actor_1_fb_likes.median(), actor_1_fb_likes.std(), actor_1_fb_likes.sum()
# 각각 최소, 최대, 평균, 중앙값 ,표준 편차, 총합
# Out:
# (0.0, 640000.0, 6494.488490527602, 982.0, 15106.986883848309, 31881444.0)

# %%
actor_1_fb_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
arr=[1,2,3,4,5,6]

# %%
arr[:2] #슬라이스
# Out:
# [1, 2]

# %%
arr[4:]
# Out:
# [5, 6]

# %%
arr[len(arr)-2:]
# Out:
# [5, 6]

# %%
arr[0:4]
# Out:
# [1, 2, 3, 4]

# %%
actor_1_fb_likes.quantile(.2) # 분위수(전체 자료를 특정 개수로 나눌때 그 기준이 되는 수)
# Out:
# 510.0

# %%
with pd.option_context('display.max_rows', 8):
    print(director.value_counts())
# Out:
# director_name
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
#                     ..
# Luca Guadagnino      1
# Sam Fell             1
# Dan Fogelman         1
# Daniel Hsia          1
# Name: count, Length: 2397, dtype: int64

# %%
# 퀴즈 -이것을 반복문으로 바꾸시오
actor_1_fb_likes.quantile([.1, .2, .3, .4, .5, .6, .7, .8, .9])
# Out:
# 0.1      240.0
# 0.2      510.0
# 0.3      694.0
# 0.4      854.0
# 0.5      982.0
# 0.6     1000.0
# 0.7     8000.0
# 0.8    13000.0
# 0.9    18000.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
# 이렇게 하세요
actor_1_fb_likes.quantile([(i+1)*.1 for i in range(9)])
# Out:
# 0.1      240.0
# 0.2      510.0
# 0.3      694.0
# 0.4      854.0
# 0.5      982.0
# 0.6     1000.0
# 0.7     8000.0
# 0.8    13000.0
# 0.9    18000.0
# Name: actor_1_facebook_likes, dtype: float64

# %%
director.isnull() # null 여부를 체크
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
director.hasnans #null값이 있는가?
# Out:
# True

# %%
director[director.notnull()] # not null인 것만 찾는다
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4910         Edward Burns
# 4911          Scott Smith
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4814, dtype: object

# %%
actor_1_fb_likes_filled = actor_1_fb_likes.fillna(0) #null인 것을 찾아 0으로 채운다
actor_1_fb_likes_filled.count
# Out:
# <bound method Series.count of 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4916, dtype: float64>

# %%
actor_1_fb_likes_dropped = actor_1_fb_likes.dropna() #null인 것을 찾아 삭제한다
actor_1_fb_likes_dropped.size
# Out:
# 4909

# %%
director.value_counts(normalize=True) # 정규화
# Out:
# director_name
# Steven Spielberg    0.005401
# Woody Allen         0.004570
# Martin Scorsese     0.004155
# Clint Eastwood      0.004155
# Ridley Scott        0.003324
#                       ...
# John Putch          0.000208
# Luca Guadagnino     0.000208
# Sam Fell            0.000208
# Dan Fogelman        0.000208
# Daniel Hsia         0.000208
# Name: proportion, Length: 2397, dtype: float64

# %%
movie.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
# 원하는 칼럼만 가져오기
movie_actor_director = movie[['actor_1_name','actor_2_name','actor_3_name','director_name']]
movie_actor_director.head()
# Out:
#   actor_1_name      actor_2_name actor_3_name  director_name
# 0  CCH Pounder  Joel David Moore    Wes Studi  James Cameron

# %%
# 문제. 랜덤하게 열의 개수 2개를 선택해 데이터를 출력하도록 하자

# %%
import random
random.randrange(0,5)
# Out:
# 4

# %%
column_names = movie.columns
data = [ column_names[int(random.random()*len(movie.columns))], column_names[int(random.random()*len(movie.columns))]]
movie[data]
# Out:
#       num_user_for_reviews  facenumber_in_poster
# 0                   3054.0                   0.0
# 1                   1238.0                   0.0
# 2                    994.0                   1.0
# 3                   2701.0                   0.0
# 4                      NaN                   0.0
# ...                    ...                   ...
# 4911                   6.0                   2.0
# 4912                 359.0                   1.0
# 4913                   3.0                   0.0
# 4914                   9.0                   5.0
# 4915                  84.0                   0.0
#
# [4916 rows x 2 columns]
